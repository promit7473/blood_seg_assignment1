# %% [markdown]
# # K-mean Thresholding

# %%
import cv2
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
from PIL import Image
import tensorflow as tf
from tensorflow import keras as K
import skimage
from skimage.io import imshow, imread, imsave
from glob import glob
import os

# %%
img = cv2.imread('./Images/bloodcells.jpg')
imshow(img)

# %%
img2 = img.reshape((-1,3))
img2=np.float32(img2)
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 10, 1.0)
k=3
attempts=10
ret,label,center=cv2.kmeans(img2,k,None,criteria,attempts,cv2.KMEANS_PP_CENTERS)
center=np.uint8(center)
res = center[label.flatten()]
res2 = res.reshape((img.shape))


imshow(res2)

# %%
# read an input image as gray
# im_gray = cv2.imread(res2,0)
im_gray = cv2.cvtColor(res2, cv2.COLOR_BGR2GRAY)
    
#blur = cv2.GaussianBlur(im_gray,(5,5),0)

# threshold it with your saved threshold
im_bw = cv2.threshold(im_gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]

imshow(im_bw)

# %% [markdown]
# # Otsu’s thresholding

# %%
im_gray = cv2.imread('Images/bloodcells.jpg', cv2.IMREAD_GRAYSCALE)
imshow(im_gray)
# Out:
# [ WARN:0@47.808] global loadsave.cpp:241 findDecoder imread_('./bloodcells.jpg'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 2
#       1 im_gray = cv2.imread('./bloodcells.jpg', cv2.IMREAD_GRAYSCALE)
# ----> 2 imshow(im_gray)
#
# File ~/.local/lib/python3.10/site-packages/skimage/io/_io.py:175, in imshow(arr, plugin, **plugin_args)
#     173 if isinstance(arr, str):
#     174     arr = call_plugin('imread', arr, plugin=plugin)
# --> 175 return call_plugin('imshow', arr, plugin=plugin, **plugin_args)
#
# File ~/.local/lib/python3.10/site-packages/skimage/io/manage_plugins.py:217, in call_plugin(kind, *args, **kwargs)
#     214     except IndexError:
#     215         raise RuntimeError(f'Could not find the plugin "{plugin}" for {kind}.')
# --> 217 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/skimage/io/_plugins/matplotlib_plugin.py:158, in imshow(image, ax, show_cbar, **kwargs)
#     155 import matplotlib.pyplot as plt
#     156 from mpl_toolkits.axes_grid1 import make_axes_locatable
# --> 158 lo, hi, cmap = _get_display_range(image)
#     160 kwargs.setdefault('interpolation', 'nearest')
#     161 kwargs.setdefault('cmap', cmap)
#
# File ~/.local/lib/python3.10/site-packages/skimage/io/_plugins/matplotlib_plugin.py:104, in _get_display_range(image)
#      89 def _get_display_range(image):
#      90     """Return the display range for a given set of image properties.
#      91
#      92     Parameters
#    (...)
#     102         The name of the colormap to use.
#     103     """
# --> 104     ip = _get_image_properties(image)
#     105     immin, immax = np.min(image), np.max(image)
#     106     if ip.signed:
#
# File ~/.local/lib/python3.10/site-packages/skimage/io/_plugins/matplotlib_plugin.py:44, in _get_image_properties(image)
#      21 """Determine nonstandard properties of an input image.
#      22
#      23 Parameters
#    (...)
#      41       standard skimage type, e.g. ``numpy.uint64``.
#      42 """
#      43 immin, immax = np.min(image), np.max(image)
# ---> 44 imtype = image.dtype.type
#      45 try:
#      46     lo, hi = dtypes.dtype_range[imtype]
#
# AttributeError: 'NoneType' object has no attribute 'dtype'

# %%
# threshold it with your saved threshold
im_bw = cv2.threshold(im_gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]

imshow(im_bw)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 4
#       1 # threshold it with your saved threshold
#       2 im_bw = cv2.threshold(im_gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]
# ----> 4 imshow(im_bw)
#
# File ~/.local/lib/python3.10/site-packages/skimage/io/_io.py:175, in imshow(arr, plugin, **plugin_args)
#     173 if isinstance(arr, str):
#     174     arr = call_plugin('imread', arr, plugin=plugin)
# --> 175 return call_plugin('imshow', arr, plugin=plugin, **plugin_args)
#
# File ~/.local/lib/python3.10/site-packages/skimage/io/manage_plugins.py:217, in call_plugin(kind, *args, **kwargs)
#     214     except IndexError:
#     215         raise RuntimeError(f'Could not find the plugin "{plugin}" for {kind}.')
# --> 217 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/skimage/io/_plugins/matplotlib_plugin.py:158, in imshow(image, ax, show_cbar, **kwargs)
#     155 import matplotlib.pyplot as plt
#     156 from mpl_toolkits.axes_grid1 import make_axes_locatable
# --> 158 lo, hi, cmap = _get_display_range(image)
#     160 kwargs.setdefault('interpolation', 'nearest')
#     161 kwargs.setdefault('cmap', cmap)
#
# File ~/.local/lib/python3.10/site-packages/skimage/io/_plugins/matplotlib_plugin.py:104, in _get_display_range(image)
#      89 def _get_display_range(image):
#      90     """Return the display range for a given set of image properties.
#      91
#      92     Parameters
#    (...)
#     102         The name of the colormap to use.
#     103     """
# --> 104     ip = _get_image_properties(image)
#     105     immin, immax = np.min(image), np.max(image)
#     106     if ip.signed:
#
# File ~/.local/lib/python3.10/site-packages/skimage/io/_plugins/matplotlib_plugin.py:44, in _get_image_properties(image)
#      21 """Determine nonstandard properties of an input image.
#      22
#      23 Parameters
#    (...)
#      41       standard skimage type, e.g. ``numpy.uint64``.
#      42 """
#      43 immin, immax = np.min(image), np.max(image)
# ---> 44 imtype = image.dtype.type
#      45 try:
#      46     lo, hi = dtypes.dtype_range[imtype]
#
# AttributeError: 'NoneType' object has no attribute 'dtype'
